# %%
import pandas as pd

# %%
df1 = pd.read_excel('CurrentEducation_IQ.xlsx')
df2 = pd.read_excel('ExerciseFactor.xlsx')
df3 = pd.read_csv('GeneralCharacterstics.csv')
df4 = pd.read_csv('OtherFactors.csv')

# %%
df1.head()
# Out:
#    StudentID  IQScore Current Education
# 0  3144076.0     90.0                 G
# 1  8046964.0     96.0                 G
# 2  7843714.0    112.0                 G
# 3  4036017.0     98.0                 G
# 4  6141936.0     99.0                 G

# %%
df2.head()
# Out:
#    StudentID Exercise
# 0  3144076.0     None
# 1  8046964.0     None
# 2  7843714.0     None
# 3  4036017.0     None
# 4        NaN      NaN

# %%
df3.head()
# Out:
#    StudentID Gender  Height  Weight   Age
# 0  3144076.0      M     5.0    62.0  21.0
# 1  8046964.0      M     4.5    69.0  18.0
# 2  7843714.0      M     5.2    68.0  20.0
# 3  4036017.0      M     6.2    49.0  19.0
# 4  6141936.0      M     4.8    45.0  18.0

# %%
df4.head()
# Out:
#   Peer Pressure Living with Family Past History Smoke  StudentID
# 0             Y                  N            Y     Y  3144076.0
# 1             Y                  N            Y     Y  8046964.0
# 2             Y                  Y            Y     Y  7843714.0
# 3             Y                  Y            Y     Y  4036017.0
# 4             N                  Y            Y     Y  6141936.0

# %%
df_merge = df1.merge(df2,on='StudentID')

# %%
df_merge = df_merge.merge(df3,on='StudentID')

# %%
df_merge = df_merge.merge(df4,on='StudentID')

# %%
df_merge.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke
# 0  21.0             Y                  N            Y     Y
# 1  18.0             Y                  N            Y     Y
# 2  20.0             Y                  Y            Y     Y
# 3  19.0             Y                  Y            Y     Y
# 4  22.0             N                  Y            Y     N

# %%
df = df_merge

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke
# 0  21.0             Y                  N            Y     Y
# 1  18.0             Y                  N            Y     Y
# 2  20.0             Y                  Y            Y     Y
# 3  19.0             Y                  Y            Y     Y
# 4  22.0             N                  Y            Y     N

# %%
d1 = pd.read_csv('Q1Responses.csv')
d2 = pd.read_excel('Q2Responses.xlsx')
d3 = pd.read_excel('Q3Responses.xlsx')
d4 = pd.read_excel('Q4Responses.xlsx')
d5 =  pd.read_csv('Q5Responses.csv')
d6 = pd.read_excel('Q6Responses.xlsx')
d7 = pd.read_excel('Q7Responses.xlsx')

# %%
d1.head()
# Out:
#    StudentID  Q1
# 0      10165   2
# 1      10281   2
# 2      11574   3
# 3      12296   2
# 4      12434   0

# %%
df.merge(d1,on = 'StudentID')
# Out:
#        StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0      3144076.0     90.0                 G      None      M     5.0    62.0
# 1      8046964.0     96.0                 G      None      M     4.5    69.0
# 2      7843714.0    112.0                 G      None      M     5.2    68.0
# 3      4036017.0     98.0                 G      None      M     6.2    49.0
# 4      9910417.0    104.0                PG  Moderate      F     5.6    77.0
# 5      1596235.0    105.0                PG  Moderate      F     5.9    70.0
# 6       620289.0     92.0                PG  Moderate      F     4.7    71.0
# 7      9778010.0     99.0                PG  Moderate      F     5.6    48.0
# 8       222071.0      NaN                PG     Heavy      M     4.6    77.0
# 9       101289.0      NaN                PG     Heavy      M     5.8    62.0
# 10     6145392.0     96.0                PG     Heavy      M     5.7    53.0
# ...

# %%
df = df.merge(d1,on = 'StudentID')

# %%
df = df.merge(d2,on = 'StudentID')

# %%
df = df.merge(d3,on = 'StudentID')

# %%
df = df.merge(d4,on = 'StudentID')

# %%
df = df.merge(d5,on = 'StudentID')

# %%
df = df.merge(d6,on = 'StudentID')

# %%
df = df.merge(d7,on = 'StudentID')

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  Q1  Q2  Q3  Q4  \
# 0  21.0             Y                  N            Y     Y   3   3   2   2
# 1  18.0             Y                  N            Y     Y   3   3   3   2
# 2  20.0             Y                  Y            Y     Y   3   3   2   3
# 3  19.0             Y                  Y            Y     Y   3   2   3   3
# 4  22.0             N                  Y            Y     N   2   2   1   1
#
#    Q5  Q6  Q7
# 0   3   3   3
# 1   3   3   2
# 2   2   2   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43468 entries, 0 to 43467
# Data columns (total 19 columns):
# StudentID             43468 non-null float64
# IQScore               43458 non-null float64
# Current Education     43460 non-null object
# Exercise              43457 non-null object
# Gender                43468 non-null object
# Height                43462 non-null float64
# Weight                43463 non-null float64
# Age                   43454 non-null float64
# Peer Pressure         43462 non-null object
# Living with Family    43457 non-null object
# Past History          43463 non-null object
# Smoke                 43463 non-null object
# Q1                    43468 non-null int64
# Q2                    43468 non-null int64
# Q3                    43468 non-null int64
# Q4                    43468 non-null int64
# Q5                    43468 non-null int64
# Q6                    43468 non-null int64
# Q7                    43468 non-null int64
# ...

# %%
df['Exercise'].value_counts()
# Out:
# None        21467
# Heavy       11762
# Moderate    10228
# Name: Exercise, dtype: int64

# %%
df.isna().sum()
# Out:
# StudentID              0
# IQScore               10
# Current Education      8
# Exercise              11
# Gender                 0
# Height                 6
# Weight                 5
# Age                   14
# Peer Pressure          6
# Living with Family    11
# Past History           5
# Smoke                  5
# Q1                     0
# Q2                     0
# Q3                     0
# Q4                     0
# Q5                     0
# Q6                     0
# Q7                     0
# dtype: int64

# %%
df['HADS'] = df['Q1'] + df['Q2'] + df['Q3'] + df['Q4'] + df['Q5'] + df['Q6']+ df['Q7']

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  Q1  Q2  Q3  Q4  \
# 0  21.0             Y                  N            Y     Y   3   3   2   2
# 1  18.0             Y                  N            Y     Y   3   3   3   2
# 2  20.0             Y                  Y            Y     Y   3   3   2   3
# 3  19.0             Y                  Y            Y     Y   3   2   3   3
# 4  22.0             N                  Y            Y     N   2   2   1   1
#
#    Q5  Q6  Q7  HADS
# 0   3   3   3    19
# 1   3   3   2    19
# ...

# %%
# Out:
#        StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 7      9778010.0     99.0                PG  Moderate      F     5.6    48.0
# 8       222071.0      NaN                PG     Heavy      M     4.6    77.0
# 9       101289.0      NaN                PG     Heavy      M     5.8    62.0
# 10     6145392.0     96.0                PG     Heavy      M     5.7    53.0
# 11     7287561.0     89.0                 S      None      M     4.9    45.0
# 12     9547882.0    111.0                 S      None      M     4.9    35.0
# 13     4293181.0     87.0                 S      None      F     5.4    49.0
# 14     5049198.0    104.0                 S  Moderate      F     5.3    41.0
# 15      871266.0    115.0                 S     Heavy      F     4.9    47.0
# 16     8900872.0    100.0                 S     Heavy      F     5.1    48.0
# 17     6848503.0    106.0                 S     Heavy      F     5.3    43.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43468 entries, 0 to 43467
# Data columns (total 20 columns):
# StudentID             43468 non-null float64
# IQScore               43458 non-null float64
# Current Education     43460 non-null object
# Exercise              43457 non-null object
# Gender                43468 non-null object
# Height                43462 non-null float64
# Weight                43463 non-null float64
# Age                   43454 non-null float64
# Peer Pressure         43462 non-null object
# Living with Family    43457 non-null object
# Past History          43463 non-null object
# Smoke                 43463 non-null object
# Q1                    43468 non-null int64
# Q2                    43468 non-null int64
# Q3                    43468 non-null int64
# Q4                    43468 non-null int64
# Q5                    43468 non-null int64
# Q6                    43468 non-null int64
# Q7                    43468 non-null int64
# ...

# %%
df['Current Education'].value_counts()
# Out:
# PG    20450
# G     12779
# S     10231
# Name: Current Education, dtype: int64

# %%
df['Exercise'].value_counts()
# Out:
# None        21467
# Heavy       11762
# Moderate    10228
# Name: Exercise, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# M    23005
# F    20463
# Name: Gender, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages\IPython\core\interactiveshell.py:3296: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x012E12B0>,
# ...
#       dtype=object)

# %%
j = []
for i in df.itertuples(): 
    if(i[20]<8):
        j.append('Normal')
    elif(i[20]<11):
        j.append('Borderline Abnormal')
    else:
        j.append('Abnormal')
j
# Out:
# ['Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Abnormal',
#  'Borderline Abnormal',
#  'Borderline Abnormal',
# ...

# %%
df['HADSbin'] = j

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family  ... Smoke Q1  Q2  Q3  Q4  Q5  Q6  \
# 0  21.0             Y                  N  ...     Y  3   3   2   2   3   3
# 1  18.0             Y                  N  ...     Y  3   3   3   2   3   3
# 2  20.0             Y                  Y  ...     Y  3   3   2   3   2   2
# 3  19.0             Y                  Y  ...     Y  3   2   3   3   2   2
# 4  22.0             N                  Y  ...     N  2   2   1   1   2   0
#
#    Q7  HADS              HADSbin
# 0   3    19             Abnormal
# ...

# %%
df.to_csv('HADS1.csv',index=False)

# %%
j = []
for i in df.itertuples(): 
    if(i[20]<8):
        j.append('No')
    elif(i[20]<11):
        j.append('Maybe')
    else:
        j.append('Yes')
j
# Out:
# ['Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'Maybe',
#  'No',
#  'No',
#  'No',
#  'No',
# ...

# %%
df['Suicide Possibility'] = j

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family  ... Q1 Q2  Q3  Q4  Q5  Q6  Q7  HADS  \
# 0  21.0             Y                  N  ...  3  3   2   2   3   3   3    19
# 1  18.0             Y                  N  ...  3  3   3   2   3   3   2    19
# 2  20.0             Y                  Y  ...  3  3   2   3   2   2   3    18
# 3  19.0             Y                  Y  ...  3  2   3   3   2   2   3    18
# 4  22.0             N                  Y  ...  2  2   1   1   2   0   0     8
#
#                HADSbin  Suicide Possibility
# ...

# %%
df.drop(['Q1','Q2','Q3','Q4','Q5','Q6','Q7'],axis=1,inplace = True)

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  HADS  \
# 0  21.0             Y                  N            Y     Y    19
# 1  18.0             Y                  N            Y     Y    19
# 2  20.0             Y                  Y            Y     Y    18
# 3  19.0             Y                  Y            Y     Y    18
# 4  22.0             N                  Y            Y     N     8
#
#                HADSbin Suicide Possibility
# 0             Abnormal                 Yes
# ...

# %%
df1 = df.groupby('Smoke')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('Age')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('IQScore')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('Gender')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('Peer Pressure')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('Living with Family')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('Past History')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df['BMI'] = df['Weight']/((0.3048*df['Height'])**2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43468 entries, 0 to 43467
# Data columns (total 16 columns):
# StudentID              43468 non-null float64
# IQScore                43458 non-null float64
# Current Education      43460 non-null object
# Exercise               43457 non-null object
# Gender                 43468 non-null object
# Height                 43462 non-null float64
# Weight                 43463 non-null float64
# Age                    43454 non-null float64
# Peer Pressure          43462 non-null object
# Living with Family     43457 non-null object
# Past History           43463 non-null object
# Smoke                  43463 non-null object
# HADS                   43468 non-null int64
# HADSbin                43468 non-null object
# Suicide Possibility    43468 non-null object
# BMI                    43457 non-null float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 4.1+ MB

# %%
j = []
for i in df.itertuples(): 
    if(i[16]<=16):
        j.append('Very Severely Underweight')
    elif(i[16]<18.5):
        j.append('Underweight')
    elif(i[16]<25):
        j.append('Normal')
    elif(i[16]<30):
        j.append('Overweight')
    else:
        j.append('Obesity')
j
# Out:
# ['Overweight',
#  'Obesity',
#  'Overweight',
#  'Very Severely Underweight',
#  'Overweight',
#  'Normal',
#  'Obesity',
#  'Underweight',
#  'Obesity',
#  'Normal',
#  'Underweight',
#  'Normal',
#  'Very Severely Underweight',
#  'Underweight',
#  'Very Severely Underweight',
#  'Normal',
#  'Normal',
#  'Underweight',
#  'Underweight',
#  'Very Severely Underweight',
#  'Very Severely Underweight',
#  'Normal',
#  'Underweight',
#  'Very Severely Underweight',
#  'Normal',
#  'Underweight',
#  'Normal',
#  'Underweight',
#  'Underweight',
#  'Underweight',
#  'Normal',
#  'Underweight',
#  'Normal',
#  'Very Severely Underweight',
#  'Underweight',
#  'Very Severely Underweight',
#  'Normal',
#  'Normal',
#  'Very Severely Underweight',
#  'Very Severely Underweight',
#  'Underweight',
#  'Very Severely Underweight',
#  'Very Severely Underweight',
#  'Normal',
#  'Underweight',
#  'Underweight',
#  'Underweight',
#  'Very Severely Underweight',
#  'Underweight',
#  'Normal',
# ...

# %%
df['BMI Bin'] = j

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  HADS  \
# 0  21.0             Y                  N            Y     Y    19
# 1  18.0             Y                  N            Y     Y    19
# 2  20.0             Y                  Y            Y     Y    18
# 3  19.0             Y                  Y            Y     Y    18
# 4  22.0             N                  Y            Y     N     8
#
#                HADSbin Suicide Possibility        BMI  \
# 0             Abnormal                 Yes  26.694498
# ...

# %%
df1 = df.groupby('BMI Bin')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df1 = df.groupby('BMI Bin')['Exercise'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize =(8,5))

# %%
df.drop(['HADS'],axis=1).head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  \
# 0  21.0             Y                  N            Y     Y
# 1  18.0             Y                  N            Y     Y
# 2  20.0             Y                  Y            Y     Y
# 3  19.0             Y                  Y            Y     Y
# 4  22.0             N                  Y            Y     N
#
#                HADSbin Suicide Possibility        BMI  \
# 0             Abnormal                 Yes  26.694498
# ...

# %%
j = []
for i in df.itertuples(): 
    if(i[8]<15):
        j.append('Junior')
    elif(i[8]<20):
        j.append('Teenager')
    elif(i[8]<27):
        j.append('Young Adult')
    else:
        j.append('Adult')
j
# Out:
# ['Young Adult',
#  'Teenager',
#  'Young Adult',
#  'Teenager',
#  'Young Adult',
#  'Young Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Adult',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Young Adult',
#  'Teenager',
#  'Young Adult',
#  'Teenager',
#  'Teenager',
#  'Teenager',
#  'Teenager',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Adult',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Junior',
#  'Young Adult',
#  'Teenager',
#  'Young Adult',
#  'Teenager',
#  'Teenager',
#  'Teenager',
#  'Teenager',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Adult',
#  'Young Adult',
#  'Young Adult',
#  'Young Adult',
# ...

# %%
df['Age Category'] = j

# %%
df1 = df.groupby('Age')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True)

# %%
df1 = df.groupby('Age Category')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True)

# %%
df1 = df.groupby('Age')['Peer Pressure'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True)

# %%
df1 = df.groupby('Current Education')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True)

# %%
df1 = df.groupby('Living with Family')['Peer Pressure'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True)

# %%
df['IQScore'].min()
# Out:
# 86.0

# %%
j = []
for i in df.itertuples(): 
    if(i[2]<70):
        j.append('Definite feeble mindedness')
    elif(i[2]<80):
        j.append('Borderline deficiency')
    elif(i[2]<90):
        j.append('Dullness')
    elif(i[2]<110):
        j.append('Normal or average')
    elif(i[2]<120):
        j.append('Superior intelligence')
    elif(i[2]<141):
        j.append('Very superior intelligence')
    else:
        j.append('Genius or near genius')

# %%
df['IQScore Category'] = j
df.groupby('IQScore Category')['Suicide Possibility'].value_counts()
# Out:
# IQScore Category       Suicide Possibility
# Dullness               No                      2030
#                        Maybe                   1756
#                        Yes                     1199
# Genius or near genius  No                         9
#                        Maybe                      1
# Normal or average      Yes                    13187
#                        No                      8297
#                        Maybe                   6254
# Superior intelligence  Yes                     6933
#                        No                      1955
#                        Maybe                   1847
# Name: Suicide Possibility, dtype: int64

# %%
df1 = df[df['IQScore Category']!='Genius or near genius'].groupby('IQScore Category')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize=(8,5))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43468 entries, 0 to 43467
# Data columns (total 19 columns):
# StudentID              43468 non-null float64
# IQScore                43458 non-null float64
# Current Education      43460 non-null object
# Exercise               43457 non-null object
# Gender                 43468 non-null object
# Height                 43462 non-null float64
# Weight                 43463 non-null float64
# Age                    43454 non-null float64
# Peer Pressure          43462 non-null object
# Living with Family     43457 non-null object
# Past History           43463 non-null object
# Smoke                  43463 non-null object
# HADS                   43468 non-null int64
# HADSbin                43468 non-null object
# Suicide Possibility    43468 non-null object
# BMI                    43457 non-null float64
# BMI Bin                43468 non-null object
# Age Category           43468 non-null object
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43414 entries, 0 to 43467
# Data columns (total 19 columns):
# StudentID              43414 non-null float64
# IQScore                43414 non-null float64
# Current Education      43414 non-null object
# Exercise               43414 non-null object
# Gender                 43414 non-null object
# Height                 43414 non-null float64
# Weight                 43414 non-null float64
# Age                    43414 non-null float64
# Peer Pressure          43414 non-null object
# Living with Family     43414 non-null object
# Past History           43414 non-null object
# Smoke                  43414 non-null object
# HADS                   43414 non-null int64
# HADSbin                43414 non-null object
# Suicide Possibility    43414 non-null object
# BMI                    43414 non-null float64
# BMI Bin                43414 non-null object
# Age Category           43414 non-null object
# ...

# %%
j = []
for i in df.itertuples(): 
    
    if((i[4]== 'Moderate' or i[4]== 'Heavy') and i[12] == 'N' and (i[17]== 'Overweight' or i[17]== 'Underweight' or i[17]== 'Normal') ):
        j.append(1)
    else:
        j.append(0)

# %%
df['isHealthy'] = j

# %%
df.drop(['HADS','BMI','Age Category','Height','Exercise'],axis=1).head()
# Out:
#    StudentID  IQScore Current Education Gender  Weight   Age Peer Pressure  \
# 0  3144076.0     90.0                 G      M    62.0  21.0             Y
# 1  8046964.0     96.0                 G      M    69.0  18.0             Y
# 2  7843714.0    112.0                 G      M    68.0  20.0             Y
# 3  4036017.0     98.0                 G      M    49.0  19.0             Y
# 4  9910417.0    104.0                PG      F    77.0  22.0             N
#
#   Living with Family Past History Smoke              HADSbin  \
# 0                  N            Y     Y             Abnormal
# 1                  N            Y     Y             Abnormal
# 2                  Y            Y     Y             Abnormal
# 3                  Y            Y     Y             Abnormal
# 4                  Y            Y     N  Borderline Abnormal
#
#   Suicide Possibility                    BMI Bin       IQScore Category  \
# ...

# %%
df1 = df.groupby('isHealthy')['Suicide Possibility'].value_counts()
import matplotlib 
# %matplotlib inline
df1.unstack().plot(kind = 'bar',stacked=True,figsize=(8,5))

# %%
df.head()
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  HADS  \
# 0  21.0             Y                  N            Y     Y    19
# 1  18.0             Y                  N            Y     Y    19
# 2  20.0             Y                  Y            Y     Y    18
# 3  19.0             Y                  Y            Y     Y    18
# 4  22.0             N                  Y            Y     N     8
#
#                HADSbin Suicide Possibility        BMI  \
# 0             Abnormal                 Yes  26.694498
# ...

# %%
///Modeeling to be added

# %%
import seaborn as sns
corr = df.drop(['Q1','Q2','Q3','Q4','Q5','Q6','Q7'],axis=1).corr()
fig, ax = plt.subplots(figsize=(10,10))  
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    annot = True,
    linewidths=.5
    
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# Out:
#        IQScore              HADSbin
# 0         90.0             Abnormal
# 1         96.0             Abnormal
# 2        112.0             Abnormal
# 3         98.0             Abnormal
# 4        104.0  Borderline Abnormal
# 5        105.0  Borderline Abnormal
# 6         92.0  Borderline Abnormal
# 7         99.0               Normal
# 8          NaN               Normal
# 9          NaN               Normal
# 10        96.0               Normal
# 11        89.0               Normal
# 12       111.0               Normal
# 13        87.0               Normal
# 14       104.0               Normal
# 15       115.0               Normal
# 16       100.0               Normal
# 17       106.0               Normal
# 18        88.0               Normal
# 19        99.0             Abnormal
# 20        91.0             Abnormal
# 21       107.0             Abnormal
# 22       109.0             Abnormal
# 23        92.0             Abnormal
# 24       109.0             Abnormal
# ...

# %%
# Out:
# Abnormal               21319
# Normal                 12291
# Borderline Abnormal     9858
# Name: HADSbin, dtype: int64

# %%
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family Past History Smoke  HADS  \
# 0  21.0             Y                  N            Y     Y    19
# 1  18.0             Y                  N            Y     Y    19
# 2  20.0             Y                  Y            Y     Y    18
# 3  19.0             Y                  Y            Y     Y    18
# 4  22.0             N                  Y            Y     N     8
#
#                HADSbin
# 0             Abnormal
# 1             Abnormal
# 2             Abnormal
# 3             Abnormal
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43468 entries, 0 to 43467
# Data columns (total 14 columns):
# StudentID             43468 non-null float64
# IQScore               43458 non-null float64
# Current Education     43460 non-null object
# Exercise              43457 non-null object
# Gender                43468 non-null object
# Height                43462 non-null float64
# Weight                43463 non-null float64
# Age                   43454 non-null float64
# Peer Pressure         43462 non-null object
# Living with Family    43457 non-null object
# Past History          43463 non-null object
# Smoke                 43463 non-null object
# HADS                  43468 non-null int64
# HADSbin               43468 non-null object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 3.6+ MB

# %%
# Out:
# PG    20450
# G     12779
# S     10231
# Name: Current Education, dtype: int64

# %%
# Out:
#    StudentID  IQScore  Height  Weight   Age Past History Smoke  HADS  \
# 0  3144076.0     90.0     5.0    62.0  21.0            Y     Y    19
# 1  8046964.0     96.0     4.5    69.0  18.0            Y     Y    19
# 2  7843714.0    112.0     5.2    68.0  20.0            Y     Y    18
# 3  4036017.0     98.0     6.2    49.0  19.0            Y     Y    18
# 4  9910417.0    104.0     5.6    77.0  22.0            Y     N     8
#
#                HADSbin
# 0             Abnormal
# 1             Abnormal
# 2             Abnormal
# 3             Abnormal
# 4  Borderline Abnormal

# %%
# Out:
#    StudentID  IQScore  Height  Weight   Age  HADS              HADSbin
# 0  3144076.0     90.0     5.0    62.0  21.0    19             Abnormal
# 1  8046964.0     96.0     4.5    69.0  18.0    19             Abnormal
# 2  7843714.0    112.0     5.2    68.0  20.0    18             Abnormal
# 3  4036017.0     98.0     6.2    49.0  19.0    18             Abnormal
# 4  9910417.0    104.0     5.6    77.0  22.0     8  Borderline Abnormal

# %%
import seaborn as sns
corr = df_num.drop(['HADS'],axis=1).corr()
fig, ax = plt.subplots(figsize=(10,10))  
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    annot = True,
    linewidths=.5
    
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'E'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-3c90aa297a9d> in <module>
# ...

# %%
# Out:
#    StudentID  IQScore Current Education  Exercise Gender  Height  Weight  \
# 0  3144076.0     90.0                 G      None      M     5.0    62.0
# 1  8046964.0     96.0                 G      None      M     4.5    69.0
# 2  7843714.0    112.0                 G      None      M     5.2    68.0
# 3  4036017.0     98.0                 G      None      M     6.2    49.0
# 4  9910417.0    104.0                PG  Moderate      F     5.6    77.0
#
#     Age Peer Pressure Living with Family  ... Smoke Q1  Q2  Q3  Q4  Q5  Q6  \
# 0  21.0             Y                  N  ...     Y  3   3   2   2   3   3
# 1  18.0             Y                  N  ...     Y  3   3   3   2   3   3
# 2  20.0             Y                  Y  ...     Y  3   3   2   3   2   2
# 3  19.0             Y                  Y  ...     Y  3   2   3   3   2   2
# 4  22.0             N                  Y  ...     N  2   2   1   1   2   0
#
#    Q7  HADS              HADSbin
# 0   3    19             Abnormal
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-5f0a5353db5a> in <module>
# ----> 1 y1 = np.array(list(df[df['Exercise'] == 'None']['BMIbin']))
#       2 y2 = list(df[df['Exercise'] == 'Moderate']['BMIbin'])
#       3 y3 = list(df[df['Exercise'] == 'Heavy']['BMIbin'])
#       4
#       5 # memo of sample number
#
# NameError: name 'np' is not defined

# %%
x
